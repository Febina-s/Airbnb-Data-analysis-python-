# %% [markdown]
# ### Python project EDA and Data visualisation - AIRBNB (NEW YORK)

# %% [markdown]
# **Steps**
# 1. Importing all the lib
# 2. Loading dataset
# 3. Initial exploration
# 4. Data cleaning
# 5. Data analysis

# %% [markdown]
# **1. Importing all the libraries**

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# **Task 2. Importing dataset**

# %%
data =pd.read_csv('datasets.csv',encoding_errors='ignore')

# %% [markdown]
# **Task 3. Initial exploration**

# %%
data.head()
# Out:
#              id                                               name    host_id  \
# 0  1.312228e+06         Rental unit in Brooklyn · ★5.0 · 1 bedroom    7130382
# 1  4.527754e+07  Rental unit in New York · ★4.67 · 2 bedrooms ·...   51501835
# 2  9.710000e+17  Rental unit in New York · ★4.17 · 1 bedroom · ...  528871354
# 3  3.857863e+06  Rental unit in New York · ★4.64 · 1 bedroom · ...   19902271
# 4  4.089661e+07  Condo in New York · ★4.91 · Studio · 1 bed · 1...   61391963
#
#             host_name neighbourhood_group       neighbourhood   latitude  \
# 0              Walter            Brooklyn        Clinton Hill  40.683710
# 1            Jeniffer           Manhattan      Hell's Kitchen  40.766610
# 2              Joshua           Manhattan             Chelsea  40.750764
# 3  John And Catherine           Manhattan  Washington Heights  40.835600
# 4      Stay With Vibe           Manhattan         Murray Hill  40.751120
#
# ...

# %%
data.tail()
# Out:
#                  id                                               name  \
# 20765  2.473690e+07  Rental unit in New York · ★4.75 · 1 bedroom · ...
# 20766  2.835711e+06  Rental unit in New York · ★4.46 · 1 bedroom · ...
# 20767  5.182527e+07  Rental unit in New York · ★4.93 · 1 bedroom · ...
# 20768  7.830000e+17  Rental unit in New York · ★5.0 · 1 bedroom · 1...
# 20769  5.660000e+17  Rental unit in Queens · ★4.89 · 1 bedroom · 1 ...
#
#          host_id host_name neighbourhood_group      neighbourhood   latitude  \
# 20765  186680487   Henry D           Manhattan    Lower East Side  40.711380
# 20766    3237504     Aspen           Manhattan  Greenwich Village  40.730580
# 20767  304317395      Jeff           Manhattan     Hell's Kitchen  40.757350
# 20768  163083101   Marissa           Manhattan          Chinatown  40.713750
# 20769   93827372   Glenroy              Queens           Rosedale  40.658874
#
# ...

# %%
data.shape
# Out:
# (20770, 22)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20770 entries, 0 to 20769
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20770 non-null  float64
#  1   name                            20770 non-null  object
#  2   host_id                         20770 non-null  int64
#  3   host_name                       20770 non-null  object
#  4   neighbourhood_group             20770 non-null  object
#  5   neighbourhood                   20763 non-null  object
#  6   latitude                        20763 non-null  float64
#  7   longitude                       20763 non-null  float64
#  8   room_type                       20763 non-null  object
#  9   price                           20736 non-null  float64
#  10  minimum_nights                  20763 non-null  float64
#  11  number_of_reviews               20763 non-null  float64
# ...

# %%
data.describe()
# Out:
#                  id       host_id      latitude     longitude          price  \
# count  2.077000e+04  2.077000e+04  20763.000000  20763.000000   20736.000000
# mean   3.033858e+17  1.749049e+08     40.726821    -73.939179     187.714940
# std    3.901221e+17  1.725657e+08      0.060293      0.061403    1023.245124
# min    2.595000e+03  1.678000e+03     40.500314    -74.249840      10.000000
# 25%    2.707260e+07  2.041184e+07     40.684159    -73.980755      80.000000
# 50%    4.992852e+07  1.086990e+08     40.722890    -73.949597     125.000000
# 75%    7.220000e+17  3.143997e+08     40.763106    -73.917475     199.000000
# max    1.050000e+18  5.504035e+08     40.911147    -73.713650  100000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    20763.000000       20763.000000       20763.000000
# mean        28.558493          42.610605           1.257589
# std         33.532697          73.523401           1.904472
# ...

# %% [markdown]
# **Tak 4. Data Cleaning**

# %%
data.isnull().sum()
# Out:
# id                                 0
# name                               0
# host_id                            0
# host_name                          0
# neighbourhood_group                0
# neighbourhood                      7
# latitude                           7
# longitude                          7
# room_type                          7
# price                             34
# minimum_nights                     7
# number_of_reviews                  7
# last_review                        7
# reviews_per_month                  7
# calculated_host_listings_count     7
# availability_365                   7
# number_of_reviews_ltm              7
# license                            0
# rating                             0
# bedrooms                           0
# beds                               0
# baths                              0
# dtype: int64

# %%
#droping the missing values 
data.dropna(inplace=True)
data.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# license                           0
# rating                            0
# bedrooms                          0
# beds                              0
# baths                             0
# dtype: int64

# %%
data.shape
# Out:
# (20736, 22)

# %%
#To check duplicates
data.duplicated().sum()
# Out:
# np.int64(12)

# %%
#Duplicated values
data[data.duplicated()]
# Out:
#                  id                                               name  \
# 6      4.527754e+07  Rental unit in New York · ★4.67 · 2 bedrooms ·...
# 7      9.710000e+17  Rental unit in New York · ★4.17 · 1 bedroom · ...
# 8      3.857863e+06  Rental unit in New York · ★4.64 · 1 bedroom · ...
# 9      4.089661e+07  Condo in New York · ★4.91 · Studio · 1 bed · 1...
# 10     4.958498e+07  Rental unit in New York · ★5.0 · 1 bedroom · 1...
# 20736  7.990000e+17  Rental unit in New York · 2 bedrooms · 2 beds ...
# 20737  5.930000e+17  Rental unit in New York · ★4.79 · 2 bedrooms ·...
# 20738  9.230000e+17  Loft in New York · ★4.33 · 1 bedroom · 2 beds ...
# 20739  1.336161e+07  Rental unit in New York · ★4.89 · 2 bedrooms ·...
# 20740  5.119566e+07  Rental unit in New York · Studio · 1 bed · 1 bath
# 20741  2.523473e+07  Rental unit in New York · ★4.41 · 1 bedroom · ...
# 20742  3.339399e+06  Rental unit in New York · ★4.73 · 1 bedroom · ...
#
# ...

# %%
#delete all duplicated values
data.drop_duplicates(inplace=True)
data.duplicated().sum()
#data[data.duplicated()]
# Out:
# np.int64(0)

# %%
#to know the datatypes 
data.dtypes

#type casting id,host_id in to object 

data['id']=data['id'].astype(object)
data['host_id']=data['host_id'].astype(object)
data.dtypes
# Out:
# id                                 object
# name                               object
# host_id                            object
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                             float64
# minimum_nights                    float64
# number_of_reviews                 float64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count    float64
# availability_365                  float64
# number_of_reviews_ltm             float64
# license                            object
# rating                             object
# bedrooms                           object
# beds                                int64
# baths                              object
# dtype: object

# %% [markdown]
# ## EDA

# %% [markdown]
# **Task 5. Data analysis**

# %% [markdown]
# **Univariate Analysis**
# #### we are analysing one column at a time and knowing its distribution (speding in dataset)

# %%
#Price distribution

sns.histplot(data=data,x='price')
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.boxplot(data=data,x='price')
# Out:
# <Axes: xlabel='price'>

# %%
#Identifying outliers in price

df=data[data['price']<1500]
sns.boxplot(data=df,x='price')
# Out:
# <Axes: xlabel='price'>

# %%
#Price Distribution
plt.figure(figsize=(8,5))
sns.histplot(data=df,x='price',color='maroon',bins=110)
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license', 'rating',
#        'bedrooms', 'beds', 'baths'],
#       dtype='object')

# %%
df.groupby(by='neighbourhood_group')['price'].mean()
# Out:
# neighbourhood_group
# Bronx            107.990506
# Brooklyn         155.138317
# Manhattan        204.146014
# Queens           121.681939
# Staten Island    118.780069
# Name: price, dtype: float64

# %% [markdown]
# Feature Engineering

# %%
#price per bed

df['price per bed']=df['price']/df['beds']
df.head()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2904\4075855914.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price per bed']=df['price']/df['beds']
#                      id                                               name  \
# 0             1312228.0         Rental unit in Brooklyn · ★5.0 · 1 bedroom
# 1            45277537.0  Rental unit in New York · ★4.67 · 2 bedrooms ·...
# 2  971000000000000000.0  Rental unit in New York · ★4.17 · 1 bedroom · ...
# 3             3857863.0  Rental unit in New York · ★4.64 · 1 bedroom · ...
# 4            40896611.0  Condo in New York · ★4.91 · Studio · 1 bed · 1...
#
#      host_id           host_name neighbourhood_group       neighbourhood  \
# ...

# %%
#now the difference can see 
df.groupby(by='neighbourhood_group')['price per bed'].mean()
# Out:
# neighbourhood_group
# Bronx             74.713639
# Brooklyn          99.788493
# Manhattan        138.708057
# Queens            76.336210
# Staten Island     67.728101
# Name: price per bed, dtype: float64

# %%
#review per night 
data['review_rate'] = data['number_of_reviews'] / data['minimum_nights']
data.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license', 'rating',
#        'bedrooms', 'beds', 'baths', 'review_rate'],
#       dtype='object')

# %%
#occuppancy rate(approximating using availability_365)
data['occupancy_rate'] = 1 - (data['availability_365'] / 365)

# %%
#Estimated revenue (how much can airbnb earn in one year)
data['estimated_revenue'] = data['price'] * (data['occupancy_rate'] * 365)
data.head(2)
# Out:
#            id                                               name   host_id  \
# 0   1312228.0         Rental unit in Brooklyn · ★5.0 · 1 bedroom   7130382
# 1  45277537.0  Rental unit in New York · ★4.67 · 2 bedrooms ·...  51501835
#
#   host_name neighbourhood_group   neighbourhood  latitude  longitude  \
# 0    Walter            Brooklyn    Clinton Hill  40.68371  -73.96461
# 1  Jeniffer           Manhattan  Hell's Kitchen  40.76661  -73.98810
#
#          room_type  price  ...  availability_365  number_of_reviews_ltm  \
# 0     Private room   55.0  ...               0.0                    0.0
# 1  Entire home/apt  144.0  ...             364.0                    2.0
#
#       license  rating  bedrooms  beds          baths review_rate  \
# 0  No License       5       1.0     1  Not specified         0.1
# 1  No License    4.67       2.0     1              1         0.3
#
#   occupancy_rate  estimated_revenue
# 0        1.00000            20075.0
# ...

# %% [markdown]
# ***Bivariate Analysis***
#   (one variable dependencies to other)

# %%
#Price vs number_of_reviews
plt.figure(figsize=(8,5))
sns.scatterplot(data=df,x='number_of_reviews',y='price',alpha=0.6, hue='neighbourhood_group')
plt.title('Locality and Review dependancy')
plt.show()

# %%
#Avg price per neighbourhood groups 

plt.figure(figsize=(6,5))
sns.barplot(data=data,x='neighbourhood_group',y='price',estimator='mean')
plt.xticks(rotation=30)
plt.title('Average Price across Neighbourhood Groups')
plt.show()

# %%
## Pairplot to show relationships and distributions among key numerical features

cols = ['price', 'minimum_nights', 'number_of_reviews', 
        'reviews_per_month', 'availability_365']

sns.pairplot(data[cols], diag_kind='kde')
plt.show()

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license', 'rating',
#        'bedrooms', 'beds', 'baths'],
#       dtype='object')

# %%
# Heatmap to visualize correlations between numerical features
corr = df[['latitude', 'longitude', 'price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month','calculated_host_listings_count','availability_365','number_of_reviews_ltm', 'beds']].corr()
corr

plt.figure(figsize=(8, 6))
sns.heatmap(data=corr, annot=True)
# Out:
# <Axes: >

# %%
# Countplot showing room type distribution across neighbourhood groups

plt.figure(figsize=(10,6))
sns.countplot(data=data, x='room_type', hue='neighbourhood_group')
plt.title("Room Type Distribution by Neighbourhood Group")
plt.show()

# %%
# Boxplot to compare price distribution across different bedroom counts
data['bedrooms'] = pd.to_numeric(data['bedrooms'], errors='coerce')

plt.figure(figsize=(8,5))
sns.boxplot(data=data, x='bedrooms', y='price')
plt.title("Price vs Bedrooms")
plt.show()
